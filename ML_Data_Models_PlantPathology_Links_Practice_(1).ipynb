# %% [markdown]
# <a href="https://colab.research.google.com/github/jrobledob/AI_in_Plant_Pathology_Fall_2025/blob/main/ML_Data_Models_PlantPathology_Links_Practice_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data & Model Sources for ML in Plant Pathology (Quick Links)
#
# **Use this notebook in Google Colab** as a link hub + a few quick-start cells to pull datasets/models.
#
# --

# %% [markdown]
# ---
# ## 1) General dataset hubs
# - **Kaggle Datasets**: https://kaggle.com/datasets
# - **Kaggle Notebooks**: https://kaggle.com/code
# - **Google Dataset Search**: https://datasetsearch.research.google.com
# - **Hugging Face Datasets**: https://huggingface.co/datasets
# - **UCI ML Repository**: https://archive.ics.uci.edu

# %% [markdown]
# ---
# ## 2) Bio/omics data (transcriptomes, genomes, variants)
# - **NCBI GEO (Gene Expression Omnibus)**: https://www.ncbi.nlm.nih.gov/geo/
# - **SRA (Sequence Read Archive)**: https://www.ncbi.nlm.nih.gov/sra
# - **ENA (European Nucleotide Archive)**: https://www.ebi.ac.uk/ena
# - **NCBI Datasets (Genomes/Assembly)**: https://www.ncbi.nlm.nih.gov/datasets
# - **Ensembl Plants**: https://plants.ensembl.org
# - **Gramene**: https://www.gramene.org
# - **UniProt**: https://www.uniprot.org
# - **InterPro**: https://www.ebi.ac.uk/interpro/
# - **PHI-base (Pathogen–Host Interactions)**: https://www.phi-base.org
# - **FungiDB**: https://fungidb.org
# - **NCBI Virus**: https://www.ncbi.nlm.nih.gov/labs/virus

# %% [markdown]
# ---
# ## 3) Plant disease image datasets (CV)
# - **PlantVillage**: https://plantvillage.psu.edu  (mirrors on Kaggle)
# - **PlantDoc**: https://github.com/pratikkayal/PlantDoc-Dataset
# - **PlantDoc-Object (detection)**: https://github.com/pratikkayal/PlantDoc-Object-Detection-Dataset
# - **iNaturalist**: https://www.inaturalist.org
# - **PlantCLEF / LifeCLEF**: https://www.imageclef.org/lifeclef
# - **Roboflow Universe**: https://universe.roboflow.com

# %% [markdown]
# ---
# ## 4) Climate & geospatial (for risk/epidemiology context)
# - **ERA5 / Copernicus**: https://cds.climate.copernicus.eu
# - **NASA EarthData**: https://earthdata.nasa.gov
# - **WorldClim**: https://www.worldclim.org
# - **OpenStreetMap**: https://www.openstreetmap.org

# %% [markdown]
# ---
# ## 5) Model hubs (pretrained weights)
# - **Hugging Face Models**: https://huggingface.co/models
# - **PyTorch Hub**: https://pytorch.org/hub
# - **TensorFlow Hub**: https://www.tensorflow.org/hub
# - **Ultralytics YOLO**: https://github.com/ultralytics/ultralytics
# - **AlphaFold DB**: https://alphafold.ebi.ac.uk
# - **ESMFold (HF)**: https://huggingface.co/facebook/esmfold

# %% [markdown]
# PRACTICE

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow

# Load an official or custom model
model = YOLO("yolo11n.pt")  # Load an official Detect model

# inference
results = model.predict(source="https://ultralytics.com/images/bus.jpg", show=True)

# Plot and display the annotated image
annotated_img = results[0].plot()
cv2_imshow(annotated_img)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 97.6ms
# Speed: 5.8ms preprocess, 97.6ms inference, 133.4ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=810x1080>
